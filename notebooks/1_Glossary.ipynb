# %% [markdown]
# # Glossary
#
# |Feature           |Type   | Description                                                                                               |
# |------------------|-------|-----------------------------------------------------------------------------------------------------------|
# |ESCOLARI	       |int64  | patient's level of education                                                                              |
# |IDADE	           |float64| patient's age                                                                                             |
# |SEXO	           |int64  | patient's gender                                                                                          |
# |UFNASC	           |object | patient's birth state                                                                                     |
# |UFRESID	       |object | patient's residence state                                                                                 |
# |IBGE	           |int64  | ID of the patient's city of residence according to Brazilian Institute of Geography and Statistics (IBGE) |
# |CIDADE	           |object | patient's residence city                                                                                  |
# |CATEATEND	       |int64  | service category to diagnosis                                                                             |
# |DTCONSULT	       |object | date of first medical appointment                                                                         |
# |CLINICA	       |int64  | medical speciality of first medical appointment                                                           |
# |DIAGPREV	       |int64  | previous diagnosis ant treatment                                                                          |
# |DTDIAG	           |object | diagnosis date                                                                                            |
# |BASEDIAG	       |int64  | type of diagnosis                                                                                         |
# |TOPO	           |object | topography code according to the International Classification of Diseases (CID)                           |
# |TOPOGRUP	       |object | topography group code                                                                                     |
# |DESCTOPO	       |object | topography description                                                                                    |
# |MORFO	           |int64  | morphology code                                                                                           |
# |DESCMORFO	       |object | morphology description                                                                                    |
# |EC	               |object | clinical stage                                                                                            |
# |ECGRUP	           |object | clinical stage group                                                                                      |
# |T	               |object | describes the primary tumor site according to the [TNM](https://en.wikipedia.org/wiki/TNM_staging_system) staging system of malignant tumours                 |
# |N	               |object | describes the regional lymph node involvement according to the TNM staging system                         |
# |M	               |object | describes the presence or otherwise of distant metastatic spread according to the TNM staging system      |
# |PT                |object | post-surgical staging                                                                                     |
# |PN	               |object | post-surgical staging                                                                                     |
# |PM	               |object | post-surgical staging                                                                                     |
# |S	               |int64  | describes the levels of serum tumor markers in the blood according to the TNM staging system              |
# |G	               |int64  | the grade of the cancer cells                                                                             |
# |LOCALTNM	       |int64  | anatomical location                                                                                       |
# |IDMITOTIC	       |int64  | mitotic index                                                                                             |
# |PSA	           |int64  | prostate specific antigen                                                                                 |
# |GLEASON	       |int64  | Gleason grading system used to evaluate prostate cancer from a prostate biopsy                            |
# |OUTRACLA	       |object | other cancer classifications                                                                              |
# |META01	           |object | metastasis code according to International Classification of Diseases for Oncology (CID-O)                |
# |META02	           |object | metastasis code according to International Classification of Diseases for Oncology (CID-O)                |
# |META03	           |object | metastasis code according to International Classification of Diseases for Oncology (CID-O)                |
# |META04	           |object | metastasis code according to International Classification of Diseases for Oncology (CID-O)                |
# |DTTRAT	           |object | treatment starting date                                                                                   |
# |NAOTRAT	       |int64  | reason for not doing the treatment                                                                        |
# |TRATAMENTO	       |object | types of treatment applied                                                                                |
# |TRATHOSP	       |object | treatments done at the hospital                                                                           |
# |TRATFANTES	       |object | treatments done before/during admission outside the hospital                                              |
# |TRATFAPOS	       |object | treatments done after admission outside the hospital                                                      |
# |NENHUM	           |int64  | treatments received at the hospital: none (No=0, Yes=1)                                                   |
# |CIRURGIA	       |int64  | surgery                                                                                                   |
# |RADIO	           |int64  | radiotherapy                                                                                              |
# |QUIMIO	           |int64  | chemotherapy                                                                                              |
# |HORMONIO	       |int64  | hormone therapy                                                                                           |
# |TMO	           |int64  | bone marrow transplant                                                                                    |
# |IMUNO	           |int64  | imunotherapy                                                                                              |
# |OUTROS	           |int64  | other treatments                                                                                          |
# |NENHUMANT	       |int64  | treatments before admission: none (No=0, Yes=1)                                                           |
# |CIRURANT	       |int64  | surgery before admission                                                                                  |
# |RADIOANT	       |int64  | radiotherapy before admission                                                                             |
# |QUIMIOANT	       |int64  | chemotherapy before admission                                                                             |
# |HORMOANT	       |int64  | hormone therapy before admission                                                                          |
# |TMOANT	           |int64  | bone marrow transplant before admission                                                                   |
# |IMUNOANT	       |int64  | imunotherapy before admission                                                                             |
# |OUTROSANT	       |int64  | other treatments before admission                                                                         |
# |NENHUMAPOS	       |int64  | treatments after admission and outside the hospital: none (No=0, Yes=1)                                   |
# |CIRURAPOS	       |int64  | surgery after admission and outside the hospital                                                          |
# |RADIOAPOS	       |int64  | radiotherapy after admission and outside the hospital                                                     |
# |QUIMIOAPOS	       |int64  | chemotherapy after admission and outside the hospital                                                     |
# |HORMOAPOS	       |int64  | hormone therapy after admission and outside the hospital                                                  |
# |TMOAPOS	       |int64  | bone marrow transplant after admission and outside the hospital                                           |
# |IMUNOAPOS	       |int64  | imunotherapy after admission and outside the hospital                                                     |
# |OUTROAPOS	       |int64  | other treatments after admission and outside the hospital                                                 |
# |DTULTINFO	       |object | date of last information about the patient                                                                |
# |ULTINFO	       |int64  | last information about the patient                                                                        |
# |CONSDIAG	       |int64  | time interval between medical appointment and diagnosis                                                   |
# |TRATCONS	       |float64| time interval between medical appointment and treatment                                                   |
# |DIAGTRAT	       |float64| time interval between treatment and diagnosis                                                             |
# |ANODIAG	       |int64  | year of diagnosis                                                                                         |
# |CICI	           |object | pediatric tumor code according to the International Classification for Childhood Cancer (CICI)            |
# |CICIGRUP	       |object | pediatric tumor group code                                                                                |
# |CICISUBGRU	       |object | pediatric tumor subgroup code                                                                             |
# |FAIXAETAR	       |object | patient's age range                                                                                       |
# |LATERALI	       |int64  | tumor laterality                                                                                          |
# |INSTORIG	       |object | home institution                                                                                          |
# |DRS	           |object | regional health department, Sao Paulo state                                                               |
# |RRAS	           |int64  | regional care networks, Sao Paulo state                                                                   |
# |PERDASEG	       |int64  | loss of patient follow-up                                                                                 |
# |ERRO	           |int64  | admission with error                                                                                      |
# |DTRECIDIVA	       |object | relapse date                                                                                              |
# |RECNENHUM	       |int64  | no relapse (No=0, Yes=1)                                                                                  |
# |RECLOCAL	       |int64  | relapse site                                                                                              |
# |RECREGIO	       |int64  | regional relapse                                                                                          |
# |RECDIST	       |int64  | distant relapse/metastasis                                                                                |
# |REC01	           |object | relapse/metastasis site                                                                                   |
# |REC02	           |object | relapse/metastasis site                                                                                   |
# |REC03	           |object | relapse/metastasis site                                                                                   |
# |REC04	           |object | relapse/metastasis site                                                                                   |
# |IBGEATEN	       |int64  | institution's IBGE code                                                                                   |
# |CIDO	           |float64| morphology CID-O code                                                                                     |
# |DSCCIDO	       |object | morphology description                                                                                    |
# |HABILIT           |int64  | referential parameters for the qualification of health facilities                                         |
# |HABILIT1          |int64  | referential parameters for the qualification of health facilities (subcategories)                         |
# |HABILIT2          |int64  | referential parameters for the qualification of health facilities (categories)                            |
# |CIDADEH           |object | city where the qualifications are|
